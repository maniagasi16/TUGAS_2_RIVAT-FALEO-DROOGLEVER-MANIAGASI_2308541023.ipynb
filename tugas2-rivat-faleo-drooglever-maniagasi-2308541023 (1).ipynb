# %%
harga_pulsa = input("Berapa harga pulsa yang harus di bayar? ")
uang_di_saku = input("jumlah yang saya bayar?")
total_kembalian = int(uang_di_saku) - int(harga_pulsa)
print ("total kembalian uang saya Rp" + str(total_kembalian))
# Out:
# Berapa harga pulsa yang harus di bayar?  85000
# jumlah yang saya bayar? 100000
# total kembalian uang saya Rp15000

# %%
nama = "Rivat Faleo Drooglever Maniagasi"
pekerjaan = 'Mahasiswa'
prodi = " S1 Matematika"
institusi = 'Universitas Udayana'
print (nama + ' adalah seorang ' + pekerjaan + prodi + ' di ' + institusi)
# Out:
# Rivat Faleo Drooglever Maniagasi adalah seorang Mahasiswa S1 Matematika di Universitas Udayana

# %%
kelas = "Matematika Kelas A"
print (kelas[0:])
print (kelas[10:-1])
print (kelas[0:-7])
# Out:
# Matematika Kelas A
#  Kelas
# Matematika

# %%
harga_hp_oppo = '3200000'
harga_hp_vivo = '1500000'
harga_hp_samsung = '2500000'
harga_hp_iphone = '15000000'
harga_hp_realme = '2000000'
harga_hp_readme = '7000000'
tambah = int(harga_hp_oppo)+int(harga_hp_vivo)+int(harga_hp_samsung)+int(harga_hp_iphone)+int(harga_hp_realme)+int(harga_hp_readme)
tambah
# Out:
# 31200000

# %%
harga_baju = "65000"
harga_celana = '95000'
print(harga_baju < harga_celana)
print (harga_baju > harga_celana)
# Out:
# True
# False
